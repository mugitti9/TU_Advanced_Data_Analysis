# %%
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
#print('Using PyTorch version:', torch.__version__, ' Device:', device)

# %%
batch_size = 32

train_dataset = datasets.MNIST('./data', 
                               train=True, 
                               download=True, 
                               transform=transforms.ToTensor())

validation_dataset = datasets.MNIST('./data', 
                                    train=False, 
                                    transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, 
                                                batch_size=batch_size, 
                                                shuffle=False)

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
pltsize=1
plt.figure(figsize=(10*pltsize, pltsize))

for i in range(10):
    plt.subplot(1,10,i+1)
    plt.axis('off')
    plt.imshow(X_train[i,:,:,:].numpy().reshape(28,28), cmap="gray_r")
    plt.title('Class: '+str(y_train[i].item()))

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 50)
        self.fc1_drop = nn.Dropout(0.2)
        self.fc2 = nn.Linear(50, 50)
        self.fc2_drop = nn.Dropout(0.2)
        self.fc3 = nn.Linear(50, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = F.relu(self.fc1(x))
        x = self.fc1_drop(x)
        x = F.relu(self.fc2(x))
        x = self.fc2_drop(x)
        return F.log_softmax(self.fc3(x), dim=1)

model = Net().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=50, bias=True)
#   (fc1_drop): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=50, out_features=50, bias=True)
#   (fc2_drop): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
def train(epoch, losst, acct,  log_interval=200):
    # Set model to training mode
    model.train()
    
    total_loss = 0.0
    total_correct = 0
    
    # Loop over each batch from the training set
    for batch_idx, (data, target) in enumerate(train_loader):
        # Copy data to GPU if needed
        data = data.to(device)
        target = target.to(device)

        # Zero gradient buffers
        optimizer.zero_grad() 
        
        # Pass data through the network
        output = model(data)

        # Calculate loss
        loss = criterion(output, target)

        # Backpropagate
        loss.backward()
        
        # Update weights
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(output, 1)
        total_correct += (predicted == target).sum().item()
        
        #if batch_idx % log_interval == 0:
            #print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                #epoch, batch_idx * len(data), len(train_loader.dataset),
                #100. * batch_idx / len(train_loader), loss.data.item()))
            
    avg_loss = total_loss / len(train_loader.dataset)
    accuracy = total_correct / len(train_loader.dataset)

    losst.append(avg_loss) 
    acct.append(accuracy*100.)
    #print(avg_loss)
    #print(accuracy)

# %%
def validate(loss_vector, accuracy_vector):
    model.eval()
    val_loss, correct = 0, 0
    for data, target in validation_loader:
        data = data.to(device)
        target = target.to(device)
        output = model(data)
        val_loss += criterion(output, target).data.item()
        pred = output.data.max(1)[1] # get the index of the max log-probability
        correct += pred.eq(target.data).cpu().sum()

    val_loss /= len(validation_loader)
    loss_vector.append(val_loss)

    accuracy = 100. * correct.to(torch.float32) / len(validation_loader.dataset)
    accuracy_vector.append(accuracy)
    
    #print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        #val_loss, correct, len(validation_loader.dataset), accuracy))

# %%
# %%time
epochs = 50

lossv, accv = [], []
losst, acct = [], []
for epoch in range(1, epochs + 1):
    train(epoch, losst, acct)
    validate(lossv, accv)
# Out:
# tensor(2.3198, grad_fn=<NllLossBackward>)
# tensor(2.3064, grad_fn=<NllLossBackward>)
# tensor(2.2999, grad_fn=<NllLossBackward>)
# tensor(2.3290, grad_fn=<NllLossBackward>)
# tensor(2.3042, grad_fn=<NllLossBackward>)
# tensor(2.3210, grad_fn=<NllLossBackward>)
# tensor(2.2910, grad_fn=<NllLossBackward>)
# tensor(2.2737, grad_fn=<NllLossBackward>)
# tensor(2.3073, grad_fn=<NllLossBackward>)
# tensor(2.2957, grad_fn=<NllLossBackward>)
# tensor(2.3141, grad_fn=<NllLossBackward>)
# tensor(2.3132, grad_fn=<NllLossBackward>)
# tensor(2.3190, grad_fn=<NllLossBackward>)
# tensor(2.2995, grad_fn=<NllLossBackward>)
# tensor(2.3197, grad_fn=<NllLossBackward>)
# tensor(2.3272, grad_fn=<NllLossBackward>)
# tensor(2.3101, grad_fn=<NllLossBackward>)
# tensor(2.3123, grad_fn=<NllLossBackward>)
# tensor(2.3093, grad_fn=<NllLossBackward>)
# tensor(2.3104, grad_fn=<NllLossBackward>)
# tensor(2.3117, grad_fn=<NllLossBackward>)
# tensor(2.2863, grad_fn=<NllLossBackward>)
# tensor(2.3054, grad_fn=<NllLossBackward>)
# tensor(2.3077, grad_fn=<NllLossBackward>)
# tensor(2.3106, grad_fn=<NllLossBackward>)
# tensor(2.3147, grad_fn=<NllLossBackward>)
# tensor(2.3174, grad_fn=<NllLossBackward>)
# tensor(2.2962, grad_fn=<NllLossBackward>)
# tensor(2.2956, grad_fn=<NllLossBackward>)
# tensor(2.2709, grad_fn=<NllLossBackward>)
# tensor(2.3167, grad_fn=<NllLossBackward>)
# tensor(2.3034, grad_fn=<NllLossBackward>)
# tensor(2.3078, grad_fn=<NllLossBackward>)
# tensor(2.3106, grad_fn=<NllLossBackward>)
# tensor(2.3030, grad_fn=<NllLossBackward>)
# tensor(2.2917, grad_fn=<NllLossBackward>)
# tensor(2.3132, grad_fn=<NllLossBackward>)
# tensor(2.2822, grad_fn=<NllLossBackward>)
# tensor(2.3060, grad_fn=<NllLossBackward>)
# tensor(2.2783, grad_fn=<NllLossBackward>)
# tensor(2.2778, grad_fn=<NllLossBackward>)
# tensor(2.2822, grad_fn=<NllLossBackward>)
# tensor(2.2891, grad_fn=<NllLossBackward>)
# tensor(2.2875, grad_fn=<NllLossBackward>)
# tensor(2.3043, grad_fn=<NllLossBackward>)
# tensor(2.2957, grad_fn=<NllLossBackward>)
# tensor(2.2922, grad_fn=<NllLossBackward>)
# tensor(2.2948, grad_fn=<NllLossBackward>)
# tensor(2.2868, grad_fn=<NllLossBackward>)
# tensor(2.3108, grad_fn=<NllLossBackward>)
# tensor(2.2742, grad_fn=<NllLossBackward>)
# tensor(2.2880, grad_fn=<NllLossBackward>)
# tensor(2.2891, grad_fn=<NllLossBackward>)
# tensor(2.3115, grad_fn=<NllLossBackward>)
# tensor(2.2875, grad_fn=<NllLossBackward>)
# tensor(2.3059, grad_fn=<NllLossBackward>)
# tensor(2.3021, grad_fn=<NllLossBackward>)
# tensor(2.2993, grad_fn=<NllLossBackward>)
# tensor(2.3024, grad_fn=<NllLossBackward>)
# tensor(2.2875, grad_fn=<NllLossBackward>)
# tensor(2.2841, grad_fn=<NllLossBackward>)
# tensor(2.2676, grad_fn=<NllLossBackward>)
# tensor(2.2951, grad_fn=<NllLossBackward>)
# tensor(2.2797, grad_fn=<NllLossBackward>)
# tensor(2.2893, grad_fn=<NllLossBackward>)
# tensor(2.2876, grad_fn=<NllLossBackward>)
# tensor(2.2665, grad_fn=<NllLossBackward>)
# tensor(2.2923, grad_fn=<NllLossBackward>)
# tensor(2.2879, grad_fn=<NllLossBackward>)
# tensor(2.2916, grad_fn=<NllLossBackward>)
# tensor(2.2986, grad_fn=<NllLossBackward>)
# tensor(2.2700, grad_fn=<NllLossBackward>)
# tensor(2.2948, grad_fn=<NllLossBackward>)
# tensor(2.2780, grad_fn=<NllLossBackward>)
# tensor(2.2736, grad_fn=<NllLossBackward>)
# tensor(2.2830, grad_fn=<NllLossBackward>)
# tensor(2.2947, grad_fn=<NllLossBackward>)
# tensor(2.2790, grad_fn=<NllLossBackward>)
# tensor(2.2776, grad_fn=<NllLossBackward>)
# tensor(2.2818, grad_fn=<NllLossBackward>)
# tensor(2.2735, grad_fn=<NllLossBackward>)
# tensor(2.2704, grad_fn=<NllLossBackward>)
# tensor(2.2841, grad_fn=<NllLossBackward>)
# tensor(2.2585, grad_fn=<NllLossBackward>)
# tensor(2.2685, grad_fn=<NllLossBackward>)
# tensor(2.2849, grad_fn=<NllLossBackward>)
# tensor(2.2693, grad_fn=<NllLossBackward>)
# tensor(2.2421, grad_fn=<NllLossBackward>)
# tensor(2.3020, grad_fn=<NllLossBackward>)
# tensor(2.2822, grad_fn=<NllLossBackward>)
# tensor(2.2909, grad_fn=<NllLossBackward>)
# tensor(2.2753, grad_fn=<NllLossBackward>)
# tensor(2.2862, grad_fn=<NllLossBackward>)
# tensor(2.2602, grad_fn=<NllLossBackward>)
# tensor(2.2626, grad_fn=<NllLossBackward>)
# tensor(2.2582, grad_fn=<NllLossBackward>)
# tensor(2.2760, grad_fn=<NllLossBackward>)
# tensor(2.2727, grad_fn=<NllLossBackward>)
# tensor(2.2576, grad_fn=<NllLossBackward>)
# tensor(2.2530, grad_fn=<NllLossBackward>)
# tensor(2.2743, grad_fn=<NllLossBackward>)
# tensor(2.2547, grad_fn=<NllLossBackward>)
# tensor(2.2752, grad_fn=<NllLossBackward>)
# tensor(2.2796, grad_fn=<NllLossBackward>)
# tensor(2.2386, grad_fn=<NllLossBackward>)
# tensor(2.2392, grad_fn=<NllLossBackward>)
# tensor(2.2778, grad_fn=<NllLossBackward>)
# tensor(2.2736, grad_fn=<NllLossBackward>)
# tensor(2.2587, grad_fn=<NllLossBackward>)
# tensor(2.2847, grad_fn=<NllLossBackward>)
# tensor(2.2758, grad_fn=<NllLossBackward>)
# tensor(2.2696, grad_fn=<NllLossBackward>)
# tensor(2.2763, grad_fn=<NllLossBackward>)
# tensor(2.2384, grad_fn=<NllLossBackward>)
# tensor(2.2689, grad_fn=<NllLossBackward>)
# tensor(2.2592, grad_fn=<NllLossBackward>)
# tensor(2.2441, grad_fn=<NllLossBackward>)
# tensor(2.2510, grad_fn=<NllLossBackward>)
# tensor(2.2616, grad_fn=<NllLossBackward>)
# tensor(2.2540, grad_fn=<NllLossBackward>)
# tensor(2.2540, grad_fn=<NllLossBackward>)
# tensor(2.2483, grad_fn=<NllLossBackward>)
# tensor(2.2534, grad_fn=<NllLossBackward>)
# tensor(2.2300, grad_fn=<NllLossBackward>)
# tensor(2.2473, grad_fn=<NllLossBackward>)
# tensor(2.2267, grad_fn=<NllLossBackward>)
# tensor(2.2641, grad_fn=<NllLossBackward>)
# tensor(2.2644, grad_fn=<NllLossBackward>)
# tensor(2.2333, grad_fn=<NllLossBackward>)
# tensor(2.2614, grad_fn=<NllLossBackward>)
# tensor(2.2241, grad_fn=<NllLossBackward>)
# tensor(2.2667, grad_fn=<NllLossBackward>)
# tensor(2.2313, grad_fn=<NllLossBackward>)
# tensor(2.2476, grad_fn=<NllLossBackward>)
# tensor(2.2400, grad_fn=<NllLossBackward>)
# tensor(2.2441, grad_fn=<NllLossBackward>)
# tensor(2.2516, grad_fn=<NllLossBackward>)
# tensor(2.2557, grad_fn=<NllLossBackward>)
# tensor(2.2376, grad_fn=<NllLossBackward>)
# tensor(2.2348, grad_fn=<NllLossBackward>)
# tensor(2.2603, grad_fn=<NllLossBackward>)
# tensor(2.2464, grad_fn=<NllLossBackward>)
# tensor(2.2605, grad_fn=<NllLossBackward>)
# tensor(2.2424, grad_fn=<NllLossBackward>)
# tensor(2.2272, grad_fn=<NllLossBackward>)
# tensor(2.2351, grad_fn=<NllLossBackward>)
# tensor(2.2201, grad_fn=<NllLossBackward>)
# tensor(2.2155, grad_fn=<NllLossBackward>)
# tensor(2.2295, grad_fn=<NllLossBackward>)
# tensor(2.1991, grad_fn=<NllLossBackward>)
# tensor(2.2252, grad_fn=<NllLossBackward>)
# tensor(2.2300, grad_fn=<NllLossBackward>)
# tensor(2.2329, grad_fn=<NllLossBackward>)
# tensor(2.2234, grad_fn=<NllLossBackward>)
# tensor(2.2165, grad_fn=<NllLossBackward>)
# tensor(2.2339, grad_fn=<NllLossBackward>)
# tensor(2.1840, grad_fn=<NllLossBackward>)
# tensor(2.2431, grad_fn=<NllLossBackward>)
# tensor(2.2138, grad_fn=<NllLossBackward>)
# tensor(2.2717, grad_fn=<NllLossBackward>)
# tensor(2.1868, grad_fn=<NllLossBackward>)
# tensor(2.2145, grad_fn=<NllLossBackward>)
# tensor(2.2284, grad_fn=<NllLossBackward>)
# tensor(2.2485, grad_fn=<NllLossBackward>)
# tensor(2.1980, grad_fn=<NllLossBackward>)
# tensor(2.2568, grad_fn=<NllLossBackward>)
# tensor(2.2267, grad_fn=<NllLossBackward>)
# tensor(2.2366, grad_fn=<NllLossBackward>)
# tensor(2.2049, grad_fn=<NllLossBackward>)
# tensor(2.2264, grad_fn=<NllLossBackward>)
# tensor(2.2417, grad_fn=<NllLossBackward>)
# tensor(2.1792, grad_fn=<NllLossBackward>)
# tensor(2.1486, grad_fn=<NllLossBackward>)
# tensor(2.2629, grad_fn=<NllLossBackward>)
# tensor(2.2155, grad_fn=<NllLossBackward>)
# tensor(2.1931, grad_fn=<NllLossBackward>)
# tensor(2.2463, grad_fn=<NllLossBackward>)
# tensor(2.2377, grad_fn=<NllLossBackward>)
# tensor(2.2558, grad_fn=<NllLossBackward>)
# tensor(2.1922, grad_fn=<NllLossBackward>)
# tensor(2.1997, grad_fn=<NllLossBackward>)
# tensor(2.1878, grad_fn=<NllLossBackward>)
# tensor(2.1780, grad_fn=<NllLossBackward>)
# tensor(2.2059, grad_fn=<NllLossBackward>)
# tensor(2.1876, grad_fn=<NllLossBackward>)
# tensor(2.2373, grad_fn=<NllLossBackward>)
# tensor(2.1685, grad_fn=<NllLossBackward>)
# tensor(2.2021, grad_fn=<NllLossBackward>)
# tensor(2.2044, grad_fn=<NllLossBackward>)
# tensor(2.2333, grad_fn=<NllLossBackward>)
# tensor(2.1740, grad_fn=<NllLossBackward>)
# tensor(2.1774, grad_fn=<NllLossBackward>)
# tensor(2.1593, grad_fn=<NllLossBackward>)
# tensor(2.2083, grad_fn=<NllLossBackward>)
# tensor(2.2046, grad_fn=<NllLossBackward>)
# tensor(2.2459, grad_fn=<NllLossBackward>)
# tensor(2.2311, grad_fn=<NllLossBackward>)
# tensor(2.1890, grad_fn=<NllLossBackward>)
# tensor(2.1855, grad_fn=<NllLossBackward>)
# tensor(2.1701, grad_fn=<NllLossBackward>)
# tensor(2.1962, grad_fn=<NllLossBackward>)
# tensor(2.1400, grad_fn=<NllLossBackward>)
# tensor(2.1870, grad_fn=<NllLossBackward>)
# tensor(2.1919, grad_fn=<NllLossBackward>)
# tensor(2.1779, grad_fn=<NllLossBackward>)
# tensor(2.2221, grad_fn=<NllLossBackward>)
# tensor(2.1269, grad_fn=<NllLossBackward>)
# tensor(2.1306, grad_fn=<NllLossBackward>)
# tensor(2.1514, grad_fn=<NllLossBackward>)
# tensor(2.1163, grad_fn=<NllLossBackward>)
# tensor(2.1712, grad_fn=<NllLossBackward>)
# tensor(2.1550, grad_fn=<NllLossBackward>)
# tensor(2.1572, grad_fn=<NllLossBackward>)
# tensor(2.2044, grad_fn=<NllLossBackward>)
# tensor(2.1555, grad_fn=<NllLossBackward>)
# tensor(2.1549, grad_fn=<NllLossBackward>)
# tensor(2.1281, grad_fn=<NllLossBackward>)
# tensor(2.1595, grad_fn=<NllLossBackward>)
# tensor(2.1459, grad_fn=<NllLossBackward>)
# tensor(2.2051, grad_fn=<NllLossBackward>)
# tensor(2.1564, grad_fn=<NllLossBackward>)
# tensor(2.1498, grad_fn=<NllLossBackward>)
# tensor(2.1299, grad_fn=<NllLossBackward>)
# tensor(2.0795, grad_fn=<NllLossBackward>)
# tensor(2.1621, grad_fn=<NllLossBackward>)
# tensor(2.1256, grad_fn=<NllLossBackward>)
# tensor(2.1709, grad_fn=<NllLossBackward>)
# tensor(2.1138, grad_fn=<NllLossBackward>)
# tensor(2.1503, grad_fn=<NllLossBackward>)
# tensor(2.1751, grad_fn=<NllLossBackward>)
# tensor(2.0980, grad_fn=<NllLossBackward>)
# tensor(2.1244, grad_fn=<NllLossBackward>)
# tensor(2.0830, grad_fn=<NllLossBackward>)
# tensor(2.0920, grad_fn=<NllLossBackward>)
# tensor(2.0924, grad_fn=<NllLossBackward>)
# tensor(2.0561, grad_fn=<NllLossBackward>)
# tensor(2.2137, grad_fn=<NllLossBackward>)
# tensor(2.0920, grad_fn=<NllLossBackward>)
# tensor(2.0707, grad_fn=<NllLossBackward>)
# tensor(2.1241, grad_fn=<NllLossBackward>)
# tensor(2.0965, grad_fn=<NllLossBackward>)
# tensor(2.1054, grad_fn=<NllLossBackward>)
# tensor(2.1813, grad_fn=<NllLossBackward>)
# tensor(2.1371, grad_fn=<NllLossBackward>)
# tensor(2.0999, grad_fn=<NllLossBackward>)
# tensor(2.0785, grad_fn=<NllLossBackward>)
# tensor(2.0785, grad_fn=<NllLossBackward>)
# tensor(2.0797, grad_fn=<NllLossBackward>)
# tensor(2.1207, grad_fn=<NllLossBackward>)
# tensor(2.0981, grad_fn=<NllLossBackward>)
# tensor(2.1512, grad_fn=<NllLossBackward>)
# tensor(2.1036, grad_fn=<NllLossBackward>)
# tensor(2.1025, grad_fn=<NllLossBackward>)
# tensor(2.0196, grad_fn=<NllLossBackward>)
# tensor(2.1546, grad_fn=<NllLossBackward>)
# tensor(2.0391, grad_fn=<NllLossBackward>)
# tensor(2.1127, grad_fn=<NllLossBackward>)
# tensor(2.0503, grad_fn=<NllLossBackward>)
# tensor(2.0893, grad_fn=<NllLossBackward>)
# tensor(2.0935, grad_fn=<NllLossBackward>)
# tensor(2.0017, grad_fn=<NllLossBackward>)
# tensor(2.0695, grad_fn=<NllLossBackward>)
# tensor(2.1241, grad_fn=<NllLossBackward>)
# tensor(2.0590, grad_fn=<NllLossBackward>)
# tensor(2.0760, grad_fn=<NllLossBackward>)
# tensor(2.0790, grad_fn=<NllLossBackward>)
# tensor(2.0596, grad_fn=<NllLossBackward>)
# tensor(2.0280, grad_fn=<NllLossBackward>)
# tensor(2.0092, grad_fn=<NllLossBackward>)
# tensor(2.0632, grad_fn=<NllLossBackward>)
# tensor(2.0653, grad_fn=<NllLossBackward>)
# tensor(1.9987, grad_fn=<NllLossBackward>)
# tensor(1.9724, grad_fn=<NllLossBackward>)
# tensor(2.0846, grad_fn=<NllLossBackward>)
# tensor(2.0788, grad_fn=<NllLossBackward>)
# tensor(2.0112, grad_fn=<NllLossBackward>)
# tensor(1.9250, grad_fn=<NllLossBackward>)
# tensor(2.0376, grad_fn=<NllLossBackward>)
# tensor(2.0131, grad_fn=<NllLossBackward>)
# tensor(2.0070, grad_fn=<NllLossBackward>)
# tensor(2.0683, grad_fn=<NllLossBackward>)
# tensor(2.0385, grad_fn=<NllLossBackward>)
# tensor(2.1089, grad_fn=<NllLossBackward>)
# tensor(1.8952, grad_fn=<NllLossBackward>)
# tensor(2.0217, grad_fn=<NllLossBackward>)
# tensor(2.0629, grad_fn=<NllLossBackward>)
# tensor(1.9984, grad_fn=<NllLossBackward>)
# tensor(1.9618, grad_fn=<NllLossBackward>)
# tensor(2.0460, grad_fn=<NllLossBackward>)
# tensor(2.1128, grad_fn=<NllLossBackward>)
# tensor(2.1282, grad_fn=<NllLossBackward>)
# tensor(1.9823, grad_fn=<NllLossBackward>)
# tensor(1.9822, grad_fn=<NllLossBackward>)
# tensor(1.8981, grad_fn=<NllLossBackward>)
# tensor(1.9653, grad_fn=<NllLossBackward>)
# tensor(1.9795, grad_fn=<NllLossBackward>)
# tensor(1.9597, grad_fn=<NllLossBackward>)
# tensor(1.8501, grad_fn=<NllLossBackward>)
# tensor(1.9828, grad_fn=<NllLossBackward>)
# tensor(1.9288, grad_fn=<NllLossBackward>)
# tensor(1.9234, grad_fn=<NllLossBackward>)
# tensor(1.9419, grad_fn=<NllLossBackward>)
# tensor(1.9167, grad_fn=<NllLossBackward>)
# tensor(1.9402, grad_fn=<NllLossBackward>)
# tensor(1.9536, grad_fn=<NllLossBackward>)
# tensor(1.7703, grad_fn=<NllLossBackward>)
# tensor(1.9160, grad_fn=<NllLossBackward>)
# tensor(2.0185, grad_fn=<NllLossBackward>)
# tensor(1.9620, grad_fn=<NllLossBackward>)
# tensor(1.9767, grad_fn=<NllLossBackward>)
# tensor(1.9365, grad_fn=<NllLossBackward>)
# tensor(1.9746, grad_fn=<NllLossBackward>)
# tensor(1.8319, grad_fn=<NllLossBackward>)
# tensor(1.9540, grad_fn=<NllLossBackward>)
# tensor(1.9719, grad_fn=<NllLossBackward>)
# tensor(1.8428, grad_fn=<NllLossBackward>)
# tensor(1.9654, grad_fn=<NllLossBackward>)
# tensor(1.8481, grad_fn=<NllLossBackward>)
# tensor(1.8705, grad_fn=<NllLossBackward>)
# tensor(1.8445, grad_fn=<NllLossBackward>)
# tensor(1.7396, grad_fn=<NllLossBackward>)
# tensor(1.9254, grad_fn=<NllLossBackward>)
# tensor(1.7971, grad_fn=<NllLossBackward>)
# tensor(1.8991, grad_fn=<NllLossBackward>)
# tensor(2.0337, grad_fn=<NllLossBackward>)
# tensor(1.8335, grad_fn=<NllLossBackward>)
# tensor(1.9021, grad_fn=<NllLossBackward>)
# tensor(1.8326, grad_fn=<NllLossBackward>)
# tensor(1.9141, grad_fn=<NllLossBackward>)
# tensor(1.8885, grad_fn=<NllLossBackward>)
# tensor(1.9980, grad_fn=<NllLossBackward>)
# tensor(1.7944, grad_fn=<NllLossBackward>)
# tensor(1.8701, grad_fn=<NllLossBackward>)
# tensor(1.9227, grad_fn=<NllLossBackward>)
# tensor(1.6806, grad_fn=<NllLossBackward>)
# tensor(1.9673, grad_fn=<NllLossBackward>)
# tensor(1.7172, grad_fn=<NllLossBackward>)
# tensor(1.5352, grad_fn=<NllLossBackward>)
# tensor(1.9015, grad_fn=<NllLossBackward>)
# tensor(1.8894, grad_fn=<NllLossBackward>)
# tensor(1.8442, grad_fn=<NllLossBackward>)
# tensor(1.8817, grad_fn=<NllLossBackward>)
# tensor(1.9506, grad_fn=<NllLossBackward>)
# tensor(1.7909, grad_fn=<NllLossBackward>)
# tensor(1.8772, grad_fn=<NllLossBackward>)
# tensor(1.7446, grad_fn=<NllLossBackward>)
# tensor(1.8383, grad_fn=<NllLossBackward>)
# tensor(1.9187, grad_fn=<NllLossBackward>)
# tensor(1.8101, grad_fn=<NllLossBackward>)
# tensor(1.8412, grad_fn=<NllLossBackward>)
# tensor(1.9391, grad_fn=<NllLossBackward>)
# tensor(1.8638, grad_fn=<NllLossBackward>)
# tensor(1.7294, grad_fn=<NllLossBackward>)
# tensor(1.6854, grad_fn=<NllLossBackward>)
# tensor(1.5792, grad_fn=<NllLossBackward>)
# tensor(1.8621, grad_fn=<NllLossBackward>)
# tensor(1.8145, grad_fn=<NllLossBackward>)
# tensor(1.7928, grad_fn=<NllLossBackward>)
# tensor(1.9420, grad_fn=<NllLossBackward>)
# tensor(1.9396, grad_fn=<NllLossBackward>)
# tensor(1.7639, grad_fn=<NllLossBackward>)
# tensor(1.7077, grad_fn=<NllLossBackward>)
# tensor(1.5750, grad_fn=<NllLossBackward>)
# tensor(1.5976, grad_fn=<NllLossBackward>)
# tensor(1.6775, grad_fn=<NllLossBackward>)
# tensor(1.7691, grad_fn=<NllLossBackward>)
# tensor(1.7379, grad_fn=<NllLossBackward>)
# tensor(1.7109, grad_fn=<NllLossBackward>)
# tensor(1.7807, grad_fn=<NllLossBackward>)
# tensor(1.7485, grad_fn=<NllLossBackward>)
# tensor(1.8214, grad_fn=<NllLossBackward>)
# tensor(1.6481, grad_fn=<NllLossBackward>)
# tensor(1.6482, grad_fn=<NllLossBackward>)
# tensor(1.8109, grad_fn=<NllLossBackward>)
# tensor(1.6485, grad_fn=<NllLossBackward>)
# tensor(1.7293, grad_fn=<NllLossBackward>)
# tensor(1.6783, grad_fn=<NllLossBackward>)
# tensor(1.6288, grad_fn=<NllLossBackward>)
# tensor(1.4255, grad_fn=<NllLossBackward>)
# tensor(1.7756, grad_fn=<NllLossBackward>)
# tensor(1.6607, grad_fn=<NllLossBackward>)
# tensor(1.7918, grad_fn=<NllLossBackward>)
# tensor(1.8755, grad_fn=<NllLossBackward>)
# tensor(1.4393, grad_fn=<NllLossBackward>)
# tensor(1.5608, grad_fn=<NllLossBackward>)
# tensor(1.8549, grad_fn=<NllLossBackward>)
# tensor(1.6119, grad_fn=<NllLossBackward>)
# tensor(1.5922, grad_fn=<NllLossBackward>)
# tensor(1.6472, grad_fn=<NllLossBackward>)
# tensor(1.6268, grad_fn=<NllLossBackward>)
# tensor(1.6410, grad_fn=<NllLossBackward>)
# tensor(1.8274, grad_fn=<NllLossBackward>)
# tensor(1.5513, grad_fn=<NllLossBackward>)
# tensor(1.7126, grad_fn=<NllLossBackward>)
# tensor(1.5561, grad_fn=<NllLossBackward>)
# tensor(1.4148, grad_fn=<NllLossBackward>)
# tensor(1.7260, grad_fn=<NllLossBackward>)
# tensor(1.6229, grad_fn=<NllLossBackward>)
# tensor(1.5400, grad_fn=<NllLossBackward>)
# tensor(1.6505, grad_fn=<NllLossBackward>)
# tensor(1.5367, grad_fn=<NllLossBackward>)
# tensor(1.6004, grad_fn=<NllLossBackward>)
# tensor(1.5402, grad_fn=<NllLossBackward>)
# tensor(1.4887, grad_fn=<NllLossBackward>)
# tensor(1.5921, grad_fn=<NllLossBackward>)
# tensor(1.4932, grad_fn=<NllLossBackward>)
# tensor(1.4816, grad_fn=<NllLossBackward>)
# tensor(1.6433, grad_fn=<NllLossBackward>)
# tensor(1.6926, grad_fn=<NllLossBackward>)
# tensor(1.5094, grad_fn=<NllLossBackward>)
# tensor(1.5351, grad_fn=<NllLossBackward>)
# tensor(1.4477, grad_fn=<NllLossBackward>)
# tensor(1.4686, grad_fn=<NllLossBackward>)
# tensor(1.5632, grad_fn=<NllLossBackward>)
# tensor(1.4093, grad_fn=<NllLossBackward>)
# tensor(1.5892, grad_fn=<NllLossBackward>)
# tensor(1.4630, grad_fn=<NllLossBackward>)
# tensor(1.4305, grad_fn=<NllLossBackward>)
# tensor(1.5919, grad_fn=<NllLossBackward>)
# tensor(1.4439, grad_fn=<NllLossBackward>)
# tensor(1.5841, grad_fn=<NllLossBackward>)
# tensor(1.4323, grad_fn=<NllLossBackward>)
# tensor(1.5241, grad_fn=<NllLossBackward>)
# tensor(1.5755, grad_fn=<NllLossBackward>)
# tensor(1.4317, grad_fn=<NllLossBackward>)
# tensor(1.4427, grad_fn=<NllLossBackward>)
# tensor(1.5478, grad_fn=<NllLossBackward>)
# tensor(1.3719, grad_fn=<NllLossBackward>)
# tensor(1.6179, grad_fn=<NllLossBackward>)
# tensor(1.4419, grad_fn=<NllLossBackward>)
# tensor(1.4881, grad_fn=<NllLossBackward>)
# tensor(1.4261, grad_fn=<NllLossBackward>)
# tensor(1.3580, grad_fn=<NllLossBackward>)
# tensor(1.5848, grad_fn=<NllLossBackward>)
# tensor(1.4219, grad_fn=<NllLossBackward>)
# tensor(1.3656, grad_fn=<NllLossBackward>)
# tensor(1.3974, grad_fn=<NllLossBackward>)
# tensor(1.5382, grad_fn=<NllLossBackward>)
# tensor(1.4870, grad_fn=<NllLossBackward>)
# tensor(1.4635, grad_fn=<NllLossBackward>)
# tensor(1.6407, grad_fn=<NllLossBackward>)
# tensor(1.4675, grad_fn=<NllLossBackward>)
# tensor(1.5893, grad_fn=<NllLossBackward>)
# tensor(1.2488, grad_fn=<NllLossBackward>)
# tensor(1.3989, grad_fn=<NllLossBackward>)
# tensor(1.2964, grad_fn=<NllLossBackward>)
# tensor(1.3119, grad_fn=<NllLossBackward>)
# tensor(1.2352, grad_fn=<NllLossBackward>)
# tensor(1.5974, grad_fn=<NllLossBackward>)
# tensor(1.3208, grad_fn=<NllLossBackward>)
# tensor(1.3134, grad_fn=<NllLossBackward>)
# tensor(1.3069, grad_fn=<NllLossBackward>)
# tensor(1.3859, grad_fn=<NllLossBackward>)
# tensor(1.4807, grad_fn=<NllLossBackward>)
# tensor(1.6142, grad_fn=<NllLossBackward>)
# tensor(1.2161, grad_fn=<NllLossBackward>)
# tensor(1.2239, grad_fn=<NllLossBackward>)
# tensor(1.4676, grad_fn=<NllLossBackward>)
# tensor(1.3021, grad_fn=<NllLossBackward>)
# tensor(1.2667, grad_fn=<NllLossBackward>)
# tensor(1.3673, grad_fn=<NllLossBackward>)
# tensor(1.3339, grad_fn=<NllLossBackward>)
# tensor(1.1709, grad_fn=<NllLossBackward>)
# tensor(1.5525, grad_fn=<NllLossBackward>)
# tensor(1.3109, grad_fn=<NllLossBackward>)
# tensor(1.3467, grad_fn=<NllLossBackward>)
# tensor(1.3314, grad_fn=<NllLossBackward>)
# tensor(1.2254, grad_fn=<NllLossBackward>)
# tensor(1.3136, grad_fn=<NllLossBackward>)
# tensor(1.3389, grad_fn=<NllLossBackward>)
# tensor(1.2880, grad_fn=<NllLossBackward>)
# tensor(1.1683, grad_fn=<NllLossBackward>)
# tensor(1.4768, grad_fn=<NllLossBackward>)
# tensor(1.3512, grad_fn=<NllLossBackward>)
# tensor(1.1488, grad_fn=<NllLossBackward>)
# tensor(1.1424, grad_fn=<NllLossBackward>)
# tensor(1.4392, grad_fn=<NllLossBackward>)
# tensor(1.2620, grad_fn=<NllLossBackward>)
# tensor(1.3919, grad_fn=<NllLossBackward>)
# tensor(1.1267, grad_fn=<NllLossBackward>)
# tensor(1.2530, grad_fn=<NllLossBackward>)
# tensor(1.3460, grad_fn=<NllLossBackward>)
# tensor(1.1359, grad_fn=<NllLossBackward>)
# tensor(1.2458, grad_fn=<NllLossBackward>)
# tensor(1.5072, grad_fn=<NllLossBackward>)
# tensor(1.4564, grad_fn=<NllLossBackward>)
# tensor(1.2360, grad_fn=<NllLossBackward>)
# tensor(1.2833, grad_fn=<NllLossBackward>)
# tensor(1.2263, grad_fn=<NllLossBackward>)
# tensor(1.2295, grad_fn=<NllLossBackward>)
# tensor(1.3236, grad_fn=<NllLossBackward>)
# tensor(1.0091, grad_fn=<NllLossBackward>)
# tensor(1.1851, grad_fn=<NllLossBackward>)
# tensor(1.2258, grad_fn=<NllLossBackward>)
# tensor(1.2141, grad_fn=<NllLossBackward>)
# tensor(1.3346, grad_fn=<NllLossBackward>)
# tensor(1.3269, grad_fn=<NllLossBackward>)
# tensor(1.4399, grad_fn=<NllLossBackward>)
# tensor(1.3707, grad_fn=<NllLossBackward>)
# tensor(1.0775, grad_fn=<NllLossBackward>)
# tensor(1.2996, grad_fn=<NllLossBackward>)
# tensor(1.3122, grad_fn=<NllLossBackward>)
# tensor(1.2981, grad_fn=<NllLossBackward>)
# tensor(1.2806, grad_fn=<NllLossBackward>)
# tensor(1.3009, grad_fn=<NllLossBackward>)
# tensor(1.0281, grad_fn=<NllLossBackward>)
# tensor(1.2294, grad_fn=<NllLossBackward>)
# tensor(1.1048, grad_fn=<NllLossBackward>)
# tensor(1.2469, grad_fn=<NllLossBackward>)
# tensor(0.8750, grad_fn=<NllLossBackward>)
# tensor(1.2202, grad_fn=<NllLossBackward>)
# tensor(1.1592, grad_fn=<NllLossBackward>)
# tensor(1.1348, grad_fn=<NllLossBackward>)
# tensor(1.2850, grad_fn=<NllLossBackward>)
# tensor(1.2198, grad_fn=<NllLossBackward>)
# tensor(1.0150, grad_fn=<NllLossBackward>)
# tensor(1.4474, grad_fn=<NllLossBackward>)
# tensor(1.3726, grad_fn=<NllLossBackward>)
# tensor(1.0132, grad_fn=<NllLossBackward>)
# tensor(0.9375, grad_fn=<NllLossBackward>)
# tensor(0.8952, grad_fn=<NllLossBackward>)
# tensor(1.2475, grad_fn=<NllLossBackward>)
# tensor(1.4222, grad_fn=<NllLossBackward>)
# tensor(1.3018, grad_fn=<NllLossBackward>)
# tensor(1.2053, grad_fn=<NllLossBackward>)
# tensor(1.2098, grad_fn=<NllLossBackward>)
# tensor(1.2641, grad_fn=<NllLossBackward>)
# tensor(1.3094, grad_fn=<NllLossBackward>)
# tensor(1.2049, grad_fn=<NllLossBackward>)
# tensor(0.9754, grad_fn=<NllLossBackward>)
# tensor(0.9543, grad_fn=<NllLossBackward>)
# tensor(1.2102, grad_fn=<NllLossBackward>)
# tensor(0.9715, grad_fn=<NllLossBackward>)
# tensor(1.1531, grad_fn=<NllLossBackward>)
# tensor(1.0851, grad_fn=<NllLossBackward>)
# tensor(1.1982, grad_fn=<NllLossBackward>)
# tensor(1.2056, grad_fn=<NllLossBackward>)
# tensor(1.1189, grad_fn=<NllLossBackward>)
# tensor(1.2179, grad_fn=<NllLossBackward>)
# tensor(1.0224, grad_fn=<NllLossBackward>)
# tensor(1.0208, grad_fn=<NllLossBackward>)
# tensor(1.0015, grad_fn=<NllLossBackward>)
# tensor(1.2615, grad_fn=<NllLossBackward>)
# tensor(1.0800, grad_fn=<NllLossBackward>)
# tensor(1.4610, grad_fn=<NllLossBackward>)
# tensor(1.1034, grad_fn=<NllLossBackward>)
# tensor(1.1659, grad_fn=<NllLossBackward>)
# tensor(1.1487, grad_fn=<NllLossBackward>)
# tensor(1.1581, grad_fn=<NllLossBackward>)
# tensor(1.0533, grad_fn=<NllLossBackward>)
# tensor(1.1132, grad_fn=<NllLossBackward>)
# tensor(1.2870, grad_fn=<NllLossBackward>)
# tensor(1.1873, grad_fn=<NllLossBackward>)
# tensor(1.1605, grad_fn=<NllLossBackward>)
# tensor(0.9167, grad_fn=<NllLossBackward>)
# tensor(1.1988, grad_fn=<NllLossBackward>)
# tensor(0.9722, grad_fn=<NllLossBackward>)
# tensor(0.9407, grad_fn=<NllLossBackward>)
# tensor(1.0752, grad_fn=<NllLossBackward>)
# tensor(0.9739, grad_fn=<NllLossBackward>)
# tensor(1.0890, grad_fn=<NllLossBackward>)
# tensor(1.1106, grad_fn=<NllLossBackward>)
# tensor(1.2707, grad_fn=<NllLossBackward>)
# tensor(1.2886, grad_fn=<NllLossBackward>)
# tensor(1.1204, grad_fn=<NllLossBackward>)
# tensor(1.0493, grad_fn=<NllLossBackward>)
# tensor(1.1056, grad_fn=<NllLossBackward>)
# tensor(1.0500, grad_fn=<NllLossBackward>)
# tensor(1.1407, grad_fn=<NllLossBackward>)
# tensor(1.1857, grad_fn=<NllLossBackward>)
# tensor(1.1079, grad_fn=<NllLossBackward>)
# tensor(1.1112, grad_fn=<NllLossBackward>)
# tensor(0.9499, grad_fn=<NllLossBackward>)
# tensor(1.0216, grad_fn=<NllLossBackward>)
# tensor(1.0223, grad_fn=<NllLossBackward>)
# tensor(1.1790, grad_fn=<NllLossBackward>)
# tensor(1.0791, grad_fn=<NllLossBackward>)
# tensor(1.0363, grad_fn=<NllLossBackward>)
# tensor(1.0514, grad_fn=<NllLossBackward>)
# tensor(1.0951, grad_fn=<NllLossBackward>)
# tensor(0.9054, grad_fn=<NllLossBackward>)
# tensor(1.0700, grad_fn=<NllLossBackward>)
# tensor(1.0280, grad_fn=<NllLossBackward>)
# tensor(0.9711, grad_fn=<NllLossBackward>)
# tensor(0.9998, grad_fn=<NllLossBackward>)
# tensor(0.9804, grad_fn=<NllLossBackward>)
# tensor(1.3817, grad_fn=<NllLossBackward>)
# tensor(0.9078, grad_fn=<NllLossBackward>)
# tensor(1.1784, grad_fn=<NllLossBackward>)
# tensor(1.2189, grad_fn=<NllLossBackward>)
# tensor(0.9785, grad_fn=<NllLossBackward>)
# tensor(1.1432, grad_fn=<NllLossBackward>)
# tensor(0.9373, grad_fn=<NllLossBackward>)
# tensor(1.2408, grad_fn=<NllLossBackward>)
# tensor(0.8790, grad_fn=<NllLossBackward>)
# tensor(0.7788, grad_fn=<NllLossBackward>)
# tensor(1.0234, grad_fn=<NllLossBackward>)
# tensor(1.0841, grad_fn=<NllLossBackward>)
# tensor(0.9521, grad_fn=<NllLossBackward>)
# tensor(0.9954, grad_fn=<NllLossBackward>)
# tensor(0.8384, grad_fn=<NllLossBackward>)
# tensor(0.8466, grad_fn=<NllLossBackward>)
# tensor(1.0013, grad_fn=<NllLossBackward>)
# tensor(0.9489, grad_fn=<NllLossBackward>)
# tensor(1.1274, grad_fn=<NllLossBackward>)
# tensor(1.2787, grad_fn=<NllLossBackward>)
# tensor(0.9430, grad_fn=<NllLossBackward>)
# tensor(1.0594, grad_fn=<NllLossBackward>)
# tensor(0.8551, grad_fn=<NllLossBackward>)
# tensor(0.4946, grad_fn=<NllLossBackward>)
# tensor(0.9366, grad_fn=<NllLossBackward>)
# tensor(1.0068, grad_fn=<NllLossBackward>)
# tensor(1.3295, grad_fn=<NllLossBackward>)
# tensor(1.0722, grad_fn=<NllLossBackward>)
# tensor(1.1273, grad_fn=<NllLossBackward>)
# tensor(1.0227, grad_fn=<NllLossBackward>)
# tensor(0.7756, grad_fn=<NllLossBackward>)
# tensor(0.9073, grad_fn=<NllLossBackward>)
# tensor(1.1139, grad_fn=<NllLossBackward>)
# tensor(0.7389, grad_fn=<NllLossBackward>)
# tensor(0.6878, grad_fn=<NllLossBackward>)
# tensor(0.7965, grad_fn=<NllLossBackward>)
# tensor(1.2912, grad_fn=<NllLossBackward>)
# tensor(1.1205, grad_fn=<NllLossBackward>)
# tensor(0.8965, grad_fn=<NllLossBackward>)
# tensor(1.4416, grad_fn=<NllLossBackward>)
# tensor(1.0012, grad_fn=<NllLossBackward>)
# tensor(0.9762, grad_fn=<NllLossBackward>)
# tensor(0.9249, grad_fn=<NllLossBackward>)
# tensor(0.8461, grad_fn=<NllLossBackward>)
# tensor(0.7832, grad_fn=<NllLossBackward>)
# tensor(1.0110, grad_fn=<NllLossBackward>)
# tensor(0.8697, grad_fn=<NllLossBackward>)
# tensor(0.8741, grad_fn=<NllLossBackward>)
# tensor(1.1706, grad_fn=<NllLossBackward>)
# tensor(0.9411, grad_fn=<NllLossBackward>)
# tensor(1.0224, grad_fn=<NllLossBackward>)
# tensor(1.0772, grad_fn=<NllLossBackward>)
# tensor(0.9802, grad_fn=<NllLossBackward>)
# tensor(0.8564, grad_fn=<NllLossBackward>)
# tensor(0.8979, grad_fn=<NllLossBackward>)
# tensor(1.0281, grad_fn=<NllLossBackward>)
# tensor(0.9149, grad_fn=<NllLossBackward>)
# tensor(0.8409, grad_fn=<NllLossBackward>)
# tensor(1.3588, grad_fn=<NllLossBackward>)
# tensor(1.1916, grad_fn=<NllLossBackward>)
# tensor(0.8251, grad_fn=<NllLossBackward>)
# tensor(0.6311, grad_fn=<NllLossBackward>)
# tensor(0.8909, grad_fn=<NllLossBackward>)
# tensor(0.9199, grad_fn=<NllLossBackward>)
# tensor(0.8655, grad_fn=<NllLossBackward>)
# tensor(1.0707, grad_fn=<NllLossBackward>)
# tensor(0.8200, grad_fn=<NllLossBackward>)
# tensor(0.6815, grad_fn=<NllLossBackward>)
# tensor(0.9076, grad_fn=<NllLossBackward>)
# tensor(1.0361, grad_fn=<NllLossBackward>)
# tensor(0.7953, grad_fn=<NllLossBackward>)
# tensor(0.8884, grad_fn=<NllLossBackward>)
# tensor(0.8884, grad_fn=<NllLossBackward>)
# tensor(0.7492, grad_fn=<NllLossBackward>)
# tensor(0.8695, grad_fn=<NllLossBackward>)
# tensor(1.0618, grad_fn=<NllLossBackward>)
# tensor(1.1403, grad_fn=<NllLossBackward>)
# tensor(0.9191, grad_fn=<NllLossBackward>)
# tensor(1.0736, grad_fn=<NllLossBackward>)
# tensor(0.9464, grad_fn=<NllLossBackward>)
# tensor(1.1630, grad_fn=<NllLossBackward>)
# tensor(1.3505, grad_fn=<NllLossBackward>)
# tensor(0.8299, grad_fn=<NllLossBackward>)
# tensor(1.0681, grad_fn=<NllLossBackward>)
# tensor(0.8982, grad_fn=<NllLossBackward>)
# tensor(0.7799, grad_fn=<NllLossBackward>)
# tensor(0.8822, grad_fn=<NllLossBackward>)
# tensor(0.9668, grad_fn=<NllLossBackward>)
# tensor(1.1133, grad_fn=<NllLossBackward>)
# tensor(0.8806, grad_fn=<NllLossBackward>)
# tensor(0.8180, grad_fn=<NllLossBackward>)
# tensor(0.8427, grad_fn=<NllLossBackward>)
# tensor(1.0655, grad_fn=<NllLossBackward>)
# tensor(0.7865, grad_fn=<NllLossBackward>)
# tensor(0.9492, grad_fn=<NllLossBackward>)
# tensor(0.9980, grad_fn=<NllLossBackward>)
# tensor(1.0008, grad_fn=<NllLossBackward>)
# tensor(1.2276, grad_fn=<NllLossBackward>)
# tensor(0.9243, grad_fn=<NllLossBackward>)
# tensor(0.8249, grad_fn=<NllLossBackward>)
# tensor(1.0485, grad_fn=<NllLossBackward>)
# tensor(0.9446, grad_fn=<NllLossBackward>)
# tensor(1.2670, grad_fn=<NllLossBackward>)
# tensor(1.0921, grad_fn=<NllLossBackward>)
# tensor(0.9691, grad_fn=<NllLossBackward>)
# tensor(0.7246, grad_fn=<NllLossBackward>)
# tensor(0.8954, grad_fn=<NllLossBackward>)
# tensor(0.9125, grad_fn=<NllLossBackward>)
# tensor(0.8861, grad_fn=<NllLossBackward>)
# tensor(0.9953, grad_fn=<NllLossBackward>)
# tensor(0.9293, grad_fn=<NllLossBackward>)
# tensor(0.9467, grad_fn=<NllLossBackward>)
# tensor(0.7899, grad_fn=<NllLossBackward>)
# tensor(0.8185, grad_fn=<NllLossBackward>)
# tensor(0.8605, grad_fn=<NllLossBackward>)
# tensor(0.7512, grad_fn=<NllLossBackward>)
# tensor(1.0205, grad_fn=<NllLossBackward>)
# tensor(1.2759, grad_fn=<NllLossBackward>)
# tensor(0.9183, grad_fn=<NllLossBackward>)
# tensor(1.0528, grad_fn=<NllLossBackward>)
# tensor(0.9816, grad_fn=<NllLossBackward>)
# tensor(0.8141, grad_fn=<NllLossBackward>)
# tensor(0.9104, grad_fn=<NllLossBackward>)
# tensor(0.8050, grad_fn=<NllLossBackward>)
# tensor(0.9194, grad_fn=<NllLossBackward>)
# tensor(0.6707, grad_fn=<NllLossBackward>)
# tensor(0.7504, grad_fn=<NllLossBackward>)
# tensor(0.6802, grad_fn=<NllLossBackward>)
# tensor(0.8544, grad_fn=<NllLossBackward>)
# tensor(0.6455, grad_fn=<NllLossBackward>)
# tensor(0.8487, grad_fn=<NllLossBackward>)
# tensor(0.6686, grad_fn=<NllLossBackward>)
# tensor(0.8577, grad_fn=<NllLossBackward>)
# tensor(0.9568, grad_fn=<NllLossBackward>)
# tensor(0.6860, grad_fn=<NllLossBackward>)
# tensor(0.7656, grad_fn=<NllLossBackward>)
# tensor(0.7899, grad_fn=<NllLossBackward>)
# tensor(0.7421, grad_fn=<NllLossBackward>)
# tensor(1.1384, grad_fn=<NllLossBackward>)
# tensor(1.0166, grad_fn=<NllLossBackward>)
# tensor(0.9013, grad_fn=<NllLossBackward>)
# tensor(0.9631, grad_fn=<NllLossBackward>)
# tensor(0.9290, grad_fn=<NllLossBackward>)
# tensor(0.5242, grad_fn=<NllLossBackward>)
# tensor(0.5597, grad_fn=<NllLossBackward>)
# tensor(0.9187, grad_fn=<NllLossBackward>)
# tensor(0.8010, grad_fn=<NllLossBackward>)
# tensor(1.0140, grad_fn=<NllLossBackward>)
# tensor(0.7544, grad_fn=<NllLossBackward>)
# tensor(0.6277, grad_fn=<NllLossBackward>)
# tensor(0.7685, grad_fn=<NllLossBackward>)
# tensor(0.9280, grad_fn=<NllLossBackward>)
# tensor(0.9135, grad_fn=<NllLossBackward>)
# tensor(0.7750, grad_fn=<NllLossBackward>)
# tensor(0.9378, grad_fn=<NllLossBackward>)
# tensor(1.0613, grad_fn=<NllLossBackward>)
# tensor(0.8481, grad_fn=<NllLossBackward>)
# tensor(0.7864, grad_fn=<NllLossBackward>)
# tensor(0.7756, grad_fn=<NllLossBackward>)
# tensor(0.7590, grad_fn=<NllLossBackward>)
# tensor(0.9208, grad_fn=<NllLossBackward>)
# tensor(0.7656, grad_fn=<NllLossBackward>)
# tensor(0.8347, grad_fn=<NllLossBackward>)
# tensor(0.6534, grad_fn=<NllLossBackward>)
# tensor(0.7065, grad_fn=<NllLossBackward>)
# tensor(0.7979, grad_fn=<NllLossBackward>)
# tensor(0.7549, grad_fn=<NllLossBackward>)
# tensor(0.6777, grad_fn=<NllLossBackward>)
# tensor(0.6858, grad_fn=<NllLossBackward>)
# tensor(0.7095, grad_fn=<NllLossBackward>)
# tensor(0.8868, grad_fn=<NllLossBackward>)
# tensor(0.9166, grad_fn=<NllLossBackward>)
# tensor(0.9345, grad_fn=<NllLossBackward>)
# tensor(0.8089, grad_fn=<NllLossBackward>)
# tensor(0.8382, grad_fn=<NllLossBackward>)
# tensor(0.8586, grad_fn=<NllLossBackward>)
# tensor(0.7180, grad_fn=<NllLossBackward>)
# tensor(0.9268, grad_fn=<NllLossBackward>)
# tensor(0.7560, grad_fn=<NllLossBackward>)
# tensor(0.8516, grad_fn=<NllLossBackward>)
# tensor(0.6916, grad_fn=<NllLossBackward>)
# tensor(0.7012, grad_fn=<NllLossBackward>)
# tensor(1.0781, grad_fn=<NllLossBackward>)
# tensor(0.8817, grad_fn=<NllLossBackward>)
# tensor(0.9130, grad_fn=<NllLossBackward>)
# tensor(0.5367, grad_fn=<NllLossBackward>)
# tensor(1.0307, grad_fn=<NllLossBackward>)
# tensor(0.8988, grad_fn=<NllLossBackward>)
# tensor(0.6618, grad_fn=<NllLossBackward>)
# tensor(0.5928, grad_fn=<NllLossBackward>)
# tensor(0.5760, grad_fn=<NllLossBackward>)
# tensor(0.5857, grad_fn=<NllLossBackward>)
# tensor(0.8727, grad_fn=<NllLossBackward>)
# tensor(0.6410, grad_fn=<NllLossBackward>)
# tensor(0.9293, grad_fn=<NllLossBackward>)
# tensor(0.8048, grad_fn=<NllLossBackward>)
# tensor(0.7184, grad_fn=<NllLossBackward>)
# tensor(0.9141, grad_fn=<NllLossBackward>)
# tensor(0.7259, grad_fn=<NllLossBackward>)
# tensor(0.8492, grad_fn=<NllLossBackward>)
# tensor(0.7996, grad_fn=<NllLossBackward>)
# tensor(0.6483, grad_fn=<NllLossBackward>)
# tensor(0.8530, grad_fn=<NllLossBackward>)
# tensor(0.7552, grad_fn=<NllLossBackward>)
# tensor(0.9087, grad_fn=<NllLossBackward>)
# tensor(1.0052, grad_fn=<NllLossBackward>)
# tensor(0.8273, grad_fn=<NllLossBackward>)
# tensor(0.9088, grad_fn=<NllLossBackward>)
# tensor(0.5793, grad_fn=<NllLossBackward>)
# tensor(0.6131, grad_fn=<NllLossBackward>)
# tensor(0.9406, grad_fn=<NllLossBackward>)
# tensor(0.8418, grad_fn=<NllLossBackward>)
# tensor(0.8914, grad_fn=<NllLossBackward>)
# tensor(0.9017, grad_fn=<NllLossBackward>)
# tensor(1.0511, grad_fn=<NllLossBackward>)
# tensor(0.8101, grad_fn=<NllLossBackward>)
# tensor(0.8141, grad_fn=<NllLossBackward>)
# tensor(0.8639, grad_fn=<NllLossBackward>)
# tensor(0.9975, grad_fn=<NllLossBackward>)
# tensor(0.6448, grad_fn=<NllLossBackward>)
# tensor(1.0137, grad_fn=<NllLossBackward>)
# tensor(0.9994, grad_fn=<NllLossBackward>)
# tensor(1.0674, grad_fn=<NllLossBackward>)
# tensor(0.6631, grad_fn=<NllLossBackward>)
# tensor(0.7244, grad_fn=<NllLossBackward>)
# tensor(0.6868, grad_fn=<NllLossBackward>)
# tensor(0.9122, grad_fn=<NllLossBackward>)
# tensor(0.8904, grad_fn=<NllLossBackward>)
# tensor(0.6565, grad_fn=<NllLossBackward>)
# tensor(0.6323, grad_fn=<NllLossBackward>)
# tensor(0.5667, grad_fn=<NllLossBackward>)
# tensor(0.6479, grad_fn=<NllLossBackward>)
# tensor(0.8091, grad_fn=<NllLossBackward>)
# tensor(1.0869, grad_fn=<NllLossBackward>)
# tensor(0.6375, grad_fn=<NllLossBackward>)
# tensor(0.8755, grad_fn=<NllLossBackward>)
# tensor(0.7444, grad_fn=<NllLossBackward>)
# tensor(0.6868, grad_fn=<NllLossBackward>)
# tensor(0.7801, grad_fn=<NllLossBackward>)
# tensor(0.7762, grad_fn=<NllLossBackward>)
# tensor(0.6935, grad_fn=<NllLossBackward>)
# tensor(0.5464, grad_fn=<NllLossBackward>)
# tensor(0.6972, grad_fn=<NllLossBackward>)
# tensor(0.7968, grad_fn=<NllLossBackward>)
# tensor(0.6464, grad_fn=<NllLossBackward>)
# tensor(0.8365, grad_fn=<NllLossBackward>)
# tensor(0.5295, grad_fn=<NllLossBackward>)
# tensor(1.0335, grad_fn=<NllLossBackward>)
# tensor(1.2660, grad_fn=<NllLossBackward>)
# tensor(0.7824, grad_fn=<NllLossBackward>)
# tensor(0.8029, grad_fn=<NllLossBackward>)
# tensor(0.8553, grad_fn=<NllLossBackward>)
# tensor(0.9011, grad_fn=<NllLossBackward>)
# tensor(0.6017, grad_fn=<NllLossBackward>)
# tensor(0.9631, grad_fn=<NllLossBackward>)
# tensor(1.0104, grad_fn=<NllLossBackward>)
# tensor(0.6118, grad_fn=<NllLossBackward>)
# tensor(0.9925, grad_fn=<NllLossBackward>)
# tensor(0.7364, grad_fn=<NllLossBackward>)
# tensor(0.8025, grad_fn=<NllLossBackward>)
# tensor(0.7385, grad_fn=<NllLossBackward>)
# tensor(0.8808, grad_fn=<NllLossBackward>)
# tensor(0.7089, grad_fn=<NllLossBackward>)
# tensor(0.8460, grad_fn=<NllLossBackward>)
# tensor(0.6463, grad_fn=<NllLossBackward>)
# tensor(0.5514, grad_fn=<NllLossBackward>)
# tensor(0.7953, grad_fn=<NllLossBackward>)
# tensor(0.7750, grad_fn=<NllLossBackward>)
# tensor(0.9324, grad_fn=<NllLossBackward>)
# tensor(0.7557, grad_fn=<NllLossBackward>)
# tensor(0.5461, grad_fn=<NllLossBackward>)
# tensor(0.6727, grad_fn=<NllLossBackward>)
# tensor(0.7737, grad_fn=<NllLossBackward>)
# tensor(0.6859, grad_fn=<NllLossBackward>)
# tensor(0.7937, grad_fn=<NllLossBackward>)
# tensor(0.6329, grad_fn=<NllLossBackward>)
# tensor(0.7690, grad_fn=<NllLossBackward>)
# tensor(0.6946, grad_fn=<NllLossBackward>)
# tensor(0.9965, grad_fn=<NllLossBackward>)
# tensor(0.7711, grad_fn=<NllLossBackward>)
# tensor(0.6123, grad_fn=<NllLossBackward>)
# tensor(0.6481, grad_fn=<NllLossBackward>)
# tensor(0.6838, grad_fn=<NllLossBackward>)
# tensor(0.6088, grad_fn=<NllLossBackward>)
# tensor(0.7688, grad_fn=<NllLossBackward>)
# tensor(0.8366, grad_fn=<NllLossBackward>)
# tensor(0.5526, grad_fn=<NllLossBackward>)
# tensor(0.8070, grad_fn=<NllLossBackward>)
# tensor(1.3649, grad_fn=<NllLossBackward>)
# tensor(0.7459, grad_fn=<NllLossBackward>)
# tensor(0.5956, grad_fn=<NllLossBackward>)
# tensor(1.0904, grad_fn=<NllLossBackward>)
# tensor(1.0367, grad_fn=<NllLossBackward>)
# tensor(0.5592, grad_fn=<NllLossBackward>)
# tensor(0.7318, grad_fn=<NllLossBackward>)
# tensor(0.5985, grad_fn=<NllLossBackward>)
# tensor(0.5560, grad_fn=<NllLossBackward>)
# tensor(0.5973, grad_fn=<NllLossBackward>)
# tensor(0.7079, grad_fn=<NllLossBackward>)
# tensor(1.1096, grad_fn=<NllLossBackward>)
# tensor(0.9420, grad_fn=<NllLossBackward>)
# tensor(0.8676, grad_fn=<NllLossBackward>)
# tensor(0.8641, grad_fn=<NllLossBackward>)
# tensor(0.6822, grad_fn=<NllLossBackward>)
# tensor(0.9264, grad_fn=<NllLossBackward>)
# tensor(1.0100, grad_fn=<NllLossBackward>)
# tensor(0.8219, grad_fn=<NllLossBackward>)
# tensor(0.7161, grad_fn=<NllLossBackward>)
# tensor(1.0831, grad_fn=<NllLossBackward>)
# tensor(0.8306, grad_fn=<NllLossBackward>)
# tensor(0.8204, grad_fn=<NllLossBackward>)
# tensor(0.9516, grad_fn=<NllLossBackward>)
# tensor(0.7076, grad_fn=<NllLossBackward>)
# tensor(0.5133, grad_fn=<NllLossBackward>)
# tensor(0.9554, grad_fn=<NllLossBackward>)
# tensor(0.6819, grad_fn=<NllLossBackward>)
# tensor(0.6960, grad_fn=<NllLossBackward>)
# tensor(0.8481, grad_fn=<NllLossBackward>)
# tensor(0.6944, grad_fn=<NllLossBackward>)
# tensor(0.7526, grad_fn=<NllLossBackward>)
# tensor(0.8598, grad_fn=<NllLossBackward>)
# tensor(0.6268, grad_fn=<NllLossBackward>)
# tensor(0.5977, grad_fn=<NllLossBackward>)
# tensor(0.7782, grad_fn=<NllLossBackward>)
# tensor(0.8111, grad_fn=<NllLossBackward>)
# tensor(0.7515, grad_fn=<NllLossBackward>)
# tensor(0.8179, grad_fn=<NllLossBackward>)
# tensor(0.7960, grad_fn=<NllLossBackward>)
# tensor(0.6731, grad_fn=<NllLossBackward>)
# tensor(0.3156, grad_fn=<NllLossBackward>)
# tensor(0.6821, grad_fn=<NllLossBackward>)
# tensor(0.5264, grad_fn=<NllLossBackward>)
# tensor(0.5672, grad_fn=<NllLossBackward>)
# tensor(0.8102, grad_fn=<NllLossBackward>)
# tensor(0.8931, grad_fn=<NllLossBackward>)
# tensor(0.8885, grad_fn=<NllLossBackward>)
# tensor(0.3719, grad_fn=<NllLossBackward>)
# tensor(0.7607, grad_fn=<NllLossBackward>)
# tensor(0.7176, grad_fn=<NllLossBackward>)
# tensor(0.7549, grad_fn=<NllLossBackward>)
# tensor(0.9162, grad_fn=<NllLossBackward>)
# tensor(0.8534, grad_fn=<NllLossBackward>)
# tensor(0.5787, grad_fn=<NllLossBackward>)
# tensor(0.8238, grad_fn=<NllLossBackward>)
# tensor(0.6421, grad_fn=<NllLossBackward>)
# tensor(0.7687, grad_fn=<NllLossBackward>)
# tensor(0.7144, grad_fn=<NllLossBackward>)
# tensor(0.4757, grad_fn=<NllLossBackward>)
# tensor(0.6087, grad_fn=<NllLossBackward>)
# tensor(0.6115, grad_fn=<NllLossBackward>)
# tensor(0.8152, grad_fn=<NllLossBackward>)
# tensor(0.7261, grad_fn=<NllLossBackward>)
# tensor(0.6052, grad_fn=<NllLossBackward>)
# tensor(0.9414, grad_fn=<NllLossBackward>)
# tensor(0.6159, grad_fn=<NllLossBackward>)
# tensor(0.7562, grad_fn=<NllLossBackward>)
# tensor(0.9040, grad_fn=<NllLossBackward>)
# tensor(0.8079, grad_fn=<NllLossBackward>)
# tensor(0.9161, grad_fn=<NllLossBackward>)
# tensor(0.6627, grad_fn=<NllLossBackward>)
# tensor(0.7217, grad_fn=<NllLossBackward>)
# tensor(0.9329, grad_fn=<NllLossBackward>)
# tensor(0.7011, grad_fn=<NllLossBackward>)
# tensor(0.7565, grad_fn=<NllLossBackward>)
# tensor(0.7696, grad_fn=<NllLossBackward>)
# tensor(0.8403, grad_fn=<NllLossBackward>)
# tensor(0.5100, grad_fn=<NllLossBackward>)
# tensor(0.9236, grad_fn=<NllLossBackward>)
# tensor(0.8517, grad_fn=<NllLossBackward>)
# tensor(0.6864, grad_fn=<NllLossBackward>)
# tensor(1.0327, grad_fn=<NllLossBackward>)
# tensor(0.7166, grad_fn=<NllLossBackward>)
# tensor(0.7137, grad_fn=<NllLossBackward>)
# tensor(0.9265, grad_fn=<NllLossBackward>)
# tensor(0.9494, grad_fn=<NllLossBackward>)
# tensor(0.7191, grad_fn=<NllLossBackward>)
# tensor(0.9257, grad_fn=<NllLossBackward>)
# tensor(0.6121, grad_fn=<NllLossBackward>)
# tensor(0.9470, grad_fn=<NllLossBackward>)
# tensor(0.7697, grad_fn=<NllLossBackward>)
# tensor(0.5871, grad_fn=<NllLossBackward>)
# tensor(0.8119, grad_fn=<NllLossBackward>)
# tensor(0.7097, grad_fn=<NllLossBackward>)
# tensor(0.7518, grad_fn=<NllLossBackward>)
# tensor(0.7272, grad_fn=<NllLossBackward>)
# tensor(0.7605, grad_fn=<NllLossBackward>)
# tensor(0.6684, grad_fn=<NllLossBackward>)
# tensor(0.6823, grad_fn=<NllLossBackward>)
# tensor(0.7502, grad_fn=<NllLossBackward>)
# tensor(0.7094, grad_fn=<NllLossBackward>)
# tensor(0.6684, grad_fn=<NllLossBackward>)
# tensor(0.6941, grad_fn=<NllLossBackward>)
# tensor(0.8956, grad_fn=<NllLossBackward>)
# tensor(0.8325, grad_fn=<NllLossBackward>)
# tensor(0.8183, grad_fn=<NllLossBackward>)
# tensor(0.5832, grad_fn=<NllLossBackward>)
# tensor(0.5576, grad_fn=<NllLossBackward>)
# tensor(0.6834, grad_fn=<NllLossBackward>)
# tensor(1.2943, grad_fn=<NllLossBackward>)
# tensor(0.9900, grad_fn=<NllLossBackward>)
# tensor(0.4986, grad_fn=<NllLossBackward>)
# tensor(1.0410, grad_fn=<NllLossBackward>)
# tensor(0.9723, grad_fn=<NllLossBackward>)
# tensor(0.6986, grad_fn=<NllLossBackward>)
# tensor(0.5265, grad_fn=<NllLossBackward>)
# tensor(0.6684, grad_fn=<NllLossBackward>)
# tensor(0.7302, grad_fn=<NllLossBackward>)
# tensor(0.7014, grad_fn=<NllLossBackward>)
# tensor(0.6513, grad_fn=<NllLossBackward>)
# tensor(0.7726, grad_fn=<NllLossBackward>)
# tensor(0.6475, grad_fn=<NllLossBackward>)
# tensor(0.4028, grad_fn=<NllLossBackward>)
# tensor(1.0137, grad_fn=<NllLossBackward>)
# tensor(0.8587, grad_fn=<NllLossBackward>)
# tensor(0.5571, grad_fn=<NllLossBackward>)
# tensor(0.8110, grad_fn=<NllLossBackward>)
# tensor(0.6260, grad_fn=<NllLossBackward>)
# tensor(0.5023, grad_fn=<NllLossBackward>)
# tensor(1.1293, grad_fn=<NllLossBackward>)
# tensor(0.8374, grad_fn=<NllLossBackward>)
# tensor(0.5798, grad_fn=<NllLossBackward>)
# tensor(0.5909, grad_fn=<NllLossBackward>)
# tensor(0.5746, grad_fn=<NllLossBackward>)
# tensor(0.8853, grad_fn=<NllLossBackward>)
# tensor(0.7607, grad_fn=<NllLossBackward>)
# tensor(0.8862, grad_fn=<NllLossBackward>)
# tensor(1.0663, grad_fn=<NllLossBackward>)
# tensor(0.7310, grad_fn=<NllLossBackward>)
# tensor(0.3091, grad_fn=<NllLossBackward>)
# tensor(0.8621, grad_fn=<NllLossBackward>)
# tensor(0.7570, grad_fn=<NllLossBackward>)
# tensor(0.5238, grad_fn=<NllLossBackward>)
# tensor(0.7088, grad_fn=<NllLossBackward>)
# tensor(1.0625, grad_fn=<NllLossBackward>)
# tensor(0.7727, grad_fn=<NllLossBackward>)
# tensor(0.7413, grad_fn=<NllLossBackward>)
# tensor(0.5861, grad_fn=<NllLossBackward>)
# tensor(0.8872, grad_fn=<NllLossBackward>)
# tensor(0.8211, grad_fn=<NllLossBackward>)
# tensor(0.6399, grad_fn=<NllLossBackward>)
# tensor(1.0654, grad_fn=<NllLossBackward>)
# tensor(1.0454, grad_fn=<NllLossBackward>)
# tensor(0.9520, grad_fn=<NllLossBackward>)
# tensor(0.5454, grad_fn=<NllLossBackward>)
# tensor(1.2457, grad_fn=<NllLossBackward>)
# tensor(0.9883, grad_fn=<NllLossBackward>)
# tensor(0.7938, grad_fn=<NllLossBackward>)
# tensor(0.6411, grad_fn=<NllLossBackward>)
# tensor(0.6997, grad_fn=<NllLossBackward>)
# tensor(0.6566, grad_fn=<NllLossBackward>)
# tensor(0.6364, grad_fn=<NllLossBackward>)
# tensor(0.7430, grad_fn=<NllLossBackward>)
# tensor(0.5542, grad_fn=<NllLossBackward>)
# tensor(0.6647, grad_fn=<NllLossBackward>)
# tensor(0.7936, grad_fn=<NllLossBackward>)
# tensor(1.0979, grad_fn=<NllLossBackward>)
# tensor(0.8648, grad_fn=<NllLossBackward>)
# tensor(1.0723, grad_fn=<NllLossBackward>)
# tensor(0.7580, grad_fn=<NllLossBackward>)
# tensor(0.5310, grad_fn=<NllLossBackward>)
# tensor(0.8827, grad_fn=<NllLossBackward>)
# tensor(0.9080, grad_fn=<NllLossBackward>)
# tensor(0.6815, grad_fn=<NllLossBackward>)
# tensor(0.6758, grad_fn=<NllLossBackward>)
# tensor(0.7078, grad_fn=<NllLossBackward>)
# tensor(0.4520, grad_fn=<NllLossBackward>)
# tensor(0.6358, grad_fn=<NllLossBackward>)
# tensor(0.6482, grad_fn=<NllLossBackward>)
# tensor(0.6093, grad_fn=<NllLossBackward>)
# tensor(0.5913, grad_fn=<NllLossBackward>)
# tensor(1.0749, grad_fn=<NllLossBackward>)
# tensor(0.5773, grad_fn=<NllLossBackward>)
# tensor(0.7031, grad_fn=<NllLossBackward>)
# tensor(0.4601, grad_fn=<NllLossBackward>)
# tensor(0.9621, grad_fn=<NllLossBackward>)
# tensor(0.8030, grad_fn=<NllLossBackward>)
# tensor(0.8791, grad_fn=<NllLossBackward>)
# tensor(0.5021, grad_fn=<NllLossBackward>)
# tensor(0.6236, grad_fn=<NllLossBackward>)
# tensor(0.8293, grad_fn=<NllLossBackward>)
# tensor(0.5197, grad_fn=<NllLossBackward>)
# tensor(0.6458, grad_fn=<NllLossBackward>)
# tensor(0.2908, grad_fn=<NllLossBackward>)
# tensor(0.9581, grad_fn=<NllLossBackward>)
# tensor(0.7257, grad_fn=<NllLossBackward>)
# tensor(0.9001, grad_fn=<NllLossBackward>)
# tensor(0.6293, grad_fn=<NllLossBackward>)
# tensor(0.5997, grad_fn=<NllLossBackward>)
# tensor(0.5910, grad_fn=<NllLossBackward>)
# tensor(0.7787, grad_fn=<NllLossBackward>)
# tensor(0.8041, grad_fn=<NllLossBackward>)
# tensor(0.7819, grad_fn=<NllLossBackward>)
# tensor(0.5667, grad_fn=<NllLossBackward>)
# tensor(0.3447, grad_fn=<NllLossBackward>)
# tensor(0.6762, grad_fn=<NllLossBackward>)
# tensor(0.7772, grad_fn=<NllLossBackward>)
# tensor(0.8076, grad_fn=<NllLossBackward>)
# tensor(0.5077, grad_fn=<NllLossBackward>)
# tensor(0.7369, grad_fn=<NllLossBackward>)
# tensor(0.8297, grad_fn=<NllLossBackward>)
# tensor(0.5710, grad_fn=<NllLossBackward>)
# tensor(0.6820, grad_fn=<NllLossBackward>)
# tensor(0.7439, grad_fn=<NllLossBackward>)
# tensor(0.5021, grad_fn=<NllLossBackward>)
# tensor(0.6045, grad_fn=<NllLossBackward>)
# tensor(0.9136, grad_fn=<NllLossBackward>)
# tensor(0.5645, grad_fn=<NllLossBackward>)
# tensor(0.5165, grad_fn=<NllLossBackward>)
# tensor(0.6205, grad_fn=<NllLossBackward>)
# tensor(0.4262, grad_fn=<NllLossBackward>)
# tensor(0.8873, grad_fn=<NllLossBackward>)
# tensor(0.8186, grad_fn=<NllLossBackward>)
# tensor(0.5542, grad_fn=<NllLossBackward>)
# tensor(0.6518, grad_fn=<NllLossBackward>)
# tensor(0.4803, grad_fn=<NllLossBackward>)
# tensor(0.5531, grad_fn=<NllLossBackward>)
# tensor(0.5336, grad_fn=<NllLossBackward>)
# tensor(0.7360, grad_fn=<NllLossBackward>)
# tensor(0.8742, grad_fn=<NllLossBackward>)
# tensor(0.4862, grad_fn=<NllLossBackward>)
# tensor(0.4506, grad_fn=<NllLossBackward>)
# tensor(0.4431, grad_fn=<NllLossBackward>)
# tensor(0.6205, grad_fn=<NllLossBackward>)
# tensor(0.5767, grad_fn=<NllLossBackward>)
# tensor(0.6318, grad_fn=<NllLossBackward>)
# tensor(0.5123, grad_fn=<NllLossBackward>)
# tensor(0.9070, grad_fn=<NllLossBackward>)
# tensor(0.8523, grad_fn=<NllLossBackward>)
# tensor(1.0128, grad_fn=<NllLossBackward>)
# tensor(0.8302, grad_fn=<NllLossBackward>)
# tensor(0.7022, grad_fn=<NllLossBackward>)
# tensor(0.6210, grad_fn=<NllLossBackward>)
# tensor(0.4940, grad_fn=<NllLossBackward>)
# tensor(0.8608, grad_fn=<NllLossBackward>)
# tensor(0.9249, grad_fn=<NllLossBackward>)
# tensor(0.6971, grad_fn=<NllLossBackward>)
# tensor(0.7141, grad_fn=<NllLossBackward>)
# tensor(0.5399, grad_fn=<NllLossBackward>)
# tensor(0.4535, grad_fn=<NllLossBackward>)
# tensor(0.9687, grad_fn=<NllLossBackward>)
# tensor(0.6070, grad_fn=<NllLossBackward>)
# tensor(0.8940, grad_fn=<NllLossBackward>)
# tensor(0.5951, grad_fn=<NllLossBackward>)
# tensor(0.8029, grad_fn=<NllLossBackward>)
# tensor(0.6279, grad_fn=<NllLossBackward>)
# tensor(0.5009, grad_fn=<NllLossBackward>)
# tensor(0.6521, grad_fn=<NllLossBackward>)
# tensor(0.5468, grad_fn=<NllLossBackward>)
# tensor(0.4333, grad_fn=<NllLossBackward>)
# tensor(0.5864, grad_fn=<NllLossBackward>)
# tensor(0.5743, grad_fn=<NllLossBackward>)
# tensor(0.6229, grad_fn=<NllLossBackward>)
# tensor(0.6996, grad_fn=<NllLossBackward>)
# tensor(0.7235, grad_fn=<NllLossBackward>)
# tensor(0.4981, grad_fn=<NllLossBackward>)
# tensor(0.4349, grad_fn=<NllLossBackward>)
# ...
# tensor(0.0945, grad_fn=<NllLossBackward>)
# tensor(0.3037, grad_fn=<NllLossBackward>)
# tensor(0.3771, grad_fn=<NllLossBackward>)
# tensor(0.0378, grad_fn=<NllLossBackward>)
# tensor(0.2269, grad_fn=<NllLossBackward>)
# tensor(0.1322, grad_fn=<NllLossBackward>)
# tensor(0.0616, grad_fn=<NllLossBackward>)
# tensor(0.2428, grad_fn=<NllLossBackward>)
# tensor(0.1424, grad_fn=<NllLossBackward>)
# tensor(0.1101, grad_fn=<NllLossBackward>)
# tensor(0.1752, grad_fn=<NllLossBackward>)
# tensor(0.0879, grad_fn=<NllLossBackward>)
# tensor(0.1188, grad_fn=<NllLossBackward>)
# tensor(0.2473, grad_fn=<NllLossBackward>)
# tensor(0.2833, grad_fn=<NllLossBackward>)
# tensor(0.1440, grad_fn=<NllLossBackward>)
# tensor(0.1290, grad_fn=<NllLossBackward>)
# tensor(0.1329, grad_fn=<NllLossBackward>)
# tensor(0.1399, grad_fn=<NllLossBackward>)
# tensor(0.2132, grad_fn=<NllLossBackward>)
# tensor(0.2227, grad_fn=<NllLossBackward>)
# tensor(0.1626, grad_fn=<NllLossBackward>)
# tensor(0.1557, grad_fn=<NllLossBackward>)
# tensor(0.0175, grad_fn=<NllLossBackward>)
# tensor(0.3781, grad_fn=<NllLossBackward>)
# tensor(0.3684, grad_fn=<NllLossBackward>)
# tensor(0.3508, grad_fn=<NllLossBackward>)
# tensor(0.2104, grad_fn=<NllLossBackward>)
# tensor(0.1472, grad_fn=<NllLossBackward>)
# tensor(0.2628, grad_fn=<NllLossBackward>)
# tensor(0.2839, grad_fn=<NllLossBackward>)
# tensor(0.3849, grad_fn=<NllLossBackward>)
# tensor(0.1471, grad_fn=<NllLossBackward>)
# tensor(0.0484, grad_fn=<NllLossBackward>)
# tensor(0.3984, grad_fn=<NllLossBackward>)
# tensor(0.2568, grad_fn=<NllLossBackward>)
# tensor(0.3023, grad_fn=<NllLossBackward>)
# tensor(0.4117, grad_fn=<NllLossBackward>)
# tensor(0.0728, grad_fn=<NllLossBackward>)
# tensor(0.0854, grad_fn=<NllLossBackward>)
# tensor(0.0483, grad_fn=<NllLossBackward>)
# tensor(0.0596, grad_fn=<NllLossBackward>)
# tensor(0.2164, grad_fn=<NllLossBackward>)
# tensor(0.1334, grad_fn=<NllLossBackward>)
# tensor(0.3769, grad_fn=<NllLossBackward>)
# tensor(0.4286, grad_fn=<NllLossBackward>)
# tensor(0.2427, grad_fn=<NllLossBackward>)
# tensor(0.0354, grad_fn=<NllLossBackward>)
# tensor(0.2213, grad_fn=<NllLossBackward>)
# tensor(0.2755, grad_fn=<NllLossBackward>)
# tensor(0.4028, grad_fn=<NllLossBackward>)
# tensor(0.3366, grad_fn=<NllLossBackward>)
# tensor(0.0595, grad_fn=<NllLossBackward>)
# tensor(0.1516, grad_fn=<NllLossBackward>)
# tensor(0.1045, grad_fn=<NllLossBackward>)
# tensor(0.1919, grad_fn=<NllLossBackward>)
# tensor(0.0853, grad_fn=<NllLossBackward>)
# tensor(0.3280, grad_fn=<NllLossBackward>)
# tensor(0.0980, grad_fn=<NllLossBackward>)
# tensor(0.1732, grad_fn=<NllLossBackward>)
# tensor(0.1141, grad_fn=<NllLossBackward>)
# tensor(0.2695, grad_fn=<NllLossBackward>)
# tensor(0.3667, grad_fn=<NllLossBackward>)
# tensor(0.1379, grad_fn=<NllLossBackward>)
# tensor(0.3963, grad_fn=<NllLossBackward>)
# tensor(0.4136, grad_fn=<NllLossBackward>)
# tensor(0.2496, grad_fn=<NllLossBackward>)
# tensor(0.1825, grad_fn=<NllLossBackward>)
# tensor(0.3239, grad_fn=<NllLossBackward>)
# tensor(0.1841, grad_fn=<NllLossBackward>)
# tensor(0.1727, grad_fn=<NllLossBackward>)
# tensor(0.2165, grad_fn=<NllLossBackward>)
# tensor(0.1841, grad_fn=<NllLossBackward>)
# tensor(0.1563, grad_fn=<NllLossBackward>)
# tensor(0.0594, grad_fn=<NllLossBackward>)
# tensor(0.2279, grad_fn=<NllLossBackward>)
# tensor(0.1814, grad_fn=<NllLossBackward>)
# tensor(0.2125, grad_fn=<NllLossBackward>)
# tensor(0.2755, grad_fn=<NllLossBackward>)
# tensor(0.0413, grad_fn=<NllLossBackward>)
# tensor(0.0969, grad_fn=<NllLossBackward>)
# tensor(0.2756, grad_fn=<NllLossBackward>)
# tensor(0.3477, grad_fn=<NllLossBackward>)
# tensor(0.1885, grad_fn=<NllLossBackward>)
# tensor(0.2270, grad_fn=<NllLossBackward>)
# tensor(0.1164, grad_fn=<NllLossBackward>)
# tensor(0.1749, grad_fn=<NllLossBackward>)
# tensor(0.3446, grad_fn=<NllLossBackward>)
# tensor(0.3479, grad_fn=<NllLossBackward>)
# tensor(0.2162, grad_fn=<NllLossBackward>)
# tensor(0.5563, grad_fn=<NllLossBackward>)
# tensor(0.2499, grad_fn=<NllLossBackward>)
# tensor(0.3990, grad_fn=<NllLossBackward>)
# tensor(0.0753, grad_fn=<NllLossBackward>)
# tensor(0.2330, grad_fn=<NllLossBackward>)
# tensor(0.1088, grad_fn=<NllLossBackward>)
# tensor(0.2462, grad_fn=<NllLossBackward>)
# tensor(0.3225, grad_fn=<NllLossBackward>)
# tensor(0.2047, grad_fn=<NllLossBackward>)
# tensor(0.2474, grad_fn=<NllLossBackward>)
# tensor(0.1312, grad_fn=<NllLossBackward>)
# tensor(0.2117, grad_fn=<NllLossBackward>)
# tensor(0.4625, grad_fn=<NllLossBackward>)
# tensor(0.3384, grad_fn=<NllLossBackward>)
# tensor(0.1862, grad_fn=<NllLossBackward>)
# tensor(0.0634, grad_fn=<NllLossBackward>)
# tensor(0.1624, grad_fn=<NllLossBackward>)
# tensor(0.2492, grad_fn=<NllLossBackward>)
# tensor(0.2091, grad_fn=<NllLossBackward>)
# tensor(0.1213, grad_fn=<NllLossBackward>)
# tensor(0.2389, grad_fn=<NllLossBackward>)
# tensor(0.0877, grad_fn=<NllLossBackward>)
# tensor(0.1811, grad_fn=<NllLossBackward>)
# tensor(0.2001, grad_fn=<NllLossBackward>)
# tensor(0.1045, grad_fn=<NllLossBackward>)
# tensor(0.2402, grad_fn=<NllLossBackward>)
# tensor(0.3771, grad_fn=<NllLossBackward>)
# tensor(0.3860, grad_fn=<NllLossBackward>)
# tensor(0.0933, grad_fn=<NllLossBackward>)
# tensor(0.2045, grad_fn=<NllLossBackward>)
# tensor(0.0735, grad_fn=<NllLossBackward>)
# tensor(0.1239, grad_fn=<NllLossBackward>)
# tensor(0.0824, grad_fn=<NllLossBackward>)
# tensor(0.1956, grad_fn=<NllLossBackward>)
# tensor(0.1426, grad_fn=<NllLossBackward>)
# tensor(0.0666, grad_fn=<NllLossBackward>)
# tensor(0.4879, grad_fn=<NllLossBackward>)
# tensor(0.0347, grad_fn=<NllLossBackward>)
# tensor(0.5062, grad_fn=<NllLossBackward>)
# tensor(0.1902, grad_fn=<NllLossBackward>)
# tensor(0.1126, grad_fn=<NllLossBackward>)
# tensor(0.3132, grad_fn=<NllLossBackward>)
# tensor(0.3469, grad_fn=<NllLossBackward>)
# tensor(0.2315, grad_fn=<NllLossBackward>)
# tensor(0.1895, grad_fn=<NllLossBackward>)
# tensor(0.2668, grad_fn=<NllLossBackward>)
# tensor(0.2932, grad_fn=<NllLossBackward>)
# tensor(0.3680, grad_fn=<NllLossBackward>)
# tensor(0.2738, grad_fn=<NllLossBackward>)
# tensor(0.2978, grad_fn=<NllLossBackward>)
# tensor(0.5976, grad_fn=<NllLossBackward>)
# tensor(0.2230, grad_fn=<NllLossBackward>)
# tensor(0.3187, grad_fn=<NllLossBackward>)
# tensor(0.0365, grad_fn=<NllLossBackward>)
# tensor(0.1041, grad_fn=<NllLossBackward>)
# tensor(0.1359, grad_fn=<NllLossBackward>)
# tensor(0.2564, grad_fn=<NllLossBackward>)
# tensor(0.2126, grad_fn=<NllLossBackward>)
# tensor(0.2917, grad_fn=<NllLossBackward>)
# tensor(0.1162, grad_fn=<NllLossBackward>)
# tensor(0.0921, grad_fn=<NllLossBackward>)
# tensor(0.1834, grad_fn=<NllLossBackward>)
# tensor(0.2118, grad_fn=<NllLossBackward>)
# tensor(0.1653, grad_fn=<NllLossBackward>)
# tensor(0.0533, grad_fn=<NllLossBackward>)
# tensor(0.1879, grad_fn=<NllLossBackward>)
# tensor(0.1106, grad_fn=<NllLossBackward>)
# tensor(0.1954, grad_fn=<NllLossBackward>)
# tensor(0.0534, grad_fn=<NllLossBackward>)
# tensor(0.1927, grad_fn=<NllLossBackward>)
# tensor(0.2115, grad_fn=<NllLossBackward>)
# tensor(0.1454, grad_fn=<NllLossBackward>)
# tensor(0.3114, grad_fn=<NllLossBackward>)
# tensor(0.0677, grad_fn=<NllLossBackward>)
# tensor(0.0402, grad_fn=<NllLossBackward>)
# tensor(0.3845, grad_fn=<NllLossBackward>)
# tensor(0.3005, grad_fn=<NllLossBackward>)
# tensor(0.3267, grad_fn=<NllLossBackward>)
# tensor(0.0489, grad_fn=<NllLossBackward>)
# tensor(0.0867, grad_fn=<NllLossBackward>)
# tensor(0.2595, grad_fn=<NllLossBackward>)
# tensor(0.2318, grad_fn=<NllLossBackward>)
# tensor(0.3229, grad_fn=<NllLossBackward>)
# tensor(0.3167, grad_fn=<NllLossBackward>)
# tensor(0.2949, grad_fn=<NllLossBackward>)
# tensor(0.3353, grad_fn=<NllLossBackward>)
# tensor(0.3285, grad_fn=<NllLossBackward>)
# tensor(0.0561, grad_fn=<NllLossBackward>)
# tensor(0.1602, grad_fn=<NllLossBackward>)
# tensor(0.2514, grad_fn=<NllLossBackward>)
# tensor(0.2788, grad_fn=<NllLossBackward>)
# tensor(0.0889, grad_fn=<NllLossBackward>)
# tensor(0.1606, grad_fn=<NllLossBackward>)
# tensor(0.0493, grad_fn=<NllLossBackward>)
# tensor(0.2787, grad_fn=<NllLossBackward>)
# tensor(0.3885, grad_fn=<NllLossBackward>)
# tensor(0.2165, grad_fn=<NllLossBackward>)
# tensor(0.1037, grad_fn=<NllLossBackward>)
# tensor(0.0924, grad_fn=<NllLossBackward>)
# tensor(0.2974, grad_fn=<NllLossBackward>)
# tensor(0.2620, grad_fn=<NllLossBackward>)
# tensor(0.0754, grad_fn=<NllLossBackward>)
# tensor(0.1026, grad_fn=<NllLossBackward>)
# tensor(0.3445, grad_fn=<NllLossBackward>)
# tensor(0.2180, grad_fn=<NllLossBackward>)
# tensor(0.1018, grad_fn=<NllLossBackward>)
# tensor(0.1350, grad_fn=<NllLossBackward>)
# tensor(0.3276, grad_fn=<NllLossBackward>)
# tensor(0.1081, grad_fn=<NllLossBackward>)
# tensor(0.5354, grad_fn=<NllLossBackward>)
# tensor(0.2171, grad_fn=<NllLossBackward>)
# tensor(0.0687, grad_fn=<NllLossBackward>)
# tensor(0.0666, grad_fn=<NllLossBackward>)
# tensor(0.1104, grad_fn=<NllLossBackward>)
# tensor(0.2529, grad_fn=<NllLossBackward>)
# tensor(0.5230, grad_fn=<NllLossBackward>)
# tensor(0.2263, grad_fn=<NllLossBackward>)
# tensor(0.5596, grad_fn=<NllLossBackward>)
# tensor(0.1371, grad_fn=<NllLossBackward>)
# tensor(0.1230, grad_fn=<NllLossBackward>)
# tensor(0.2226, grad_fn=<NllLossBackward>)
# tensor(0.6516, grad_fn=<NllLossBackward>)
# tensor(0.2347, grad_fn=<NllLossBackward>)
# tensor(0.1222, grad_fn=<NllLossBackward>)
# tensor(0.1034, grad_fn=<NllLossBackward>)
# tensor(0.1745, grad_fn=<NllLossBackward>)
# tensor(0.1655, grad_fn=<NllLossBackward>)
# tensor(0.1334, grad_fn=<NllLossBackward>)
# tensor(0.1509, grad_fn=<NllLossBackward>)
# tensor(0.1046, grad_fn=<NllLossBackward>)
# tensor(0.0933, grad_fn=<NllLossBackward>)
# tensor(0.0832, grad_fn=<NllLossBackward>)
# tensor(0.4727, grad_fn=<NllLossBackward>)
# tensor(0.1652, grad_fn=<NllLossBackward>)
# tensor(0.1251, grad_fn=<NllLossBackward>)
# tensor(0.2145, grad_fn=<NllLossBackward>)
# tensor(0.2453, grad_fn=<NllLossBackward>)
# tensor(0.1715, grad_fn=<NllLossBackward>)
# tensor(0.1064, grad_fn=<NllLossBackward>)
# tensor(0.3282, grad_fn=<NllLossBackward>)
# tensor(0.3799, grad_fn=<NllLossBackward>)
# tensor(0.2489, grad_fn=<NllLossBackward>)
# tensor(0.1193, grad_fn=<NllLossBackward>)
# tensor(0.1660, grad_fn=<NllLossBackward>)
# tensor(0.3321, grad_fn=<NllLossBackward>)
# tensor(0.2809, grad_fn=<NllLossBackward>)
# tensor(0.2337, grad_fn=<NllLossBackward>)
# tensor(0.2573, grad_fn=<NllLossBackward>)
# tensor(0.1751, grad_fn=<NllLossBackward>)
# tensor(0.2593, grad_fn=<NllLossBackward>)
# tensor(0.1039, grad_fn=<NllLossBackward>)
# tensor(0.1572, grad_fn=<NllLossBackward>)
# tensor(0.3778, grad_fn=<NllLossBackward>)
# tensor(0.1408, grad_fn=<NllLossBackward>)
# tensor(0.3130, grad_fn=<NllLossBackward>)
# tensor(0.1834, grad_fn=<NllLossBackward>)
# tensor(0.1214, grad_fn=<NllLossBackward>)
# tensor(0.1050, grad_fn=<NllLossBackward>)
# tensor(0.1982, grad_fn=<NllLossBackward>)
# tensor(0.4840, grad_fn=<NllLossBackward>)
# tensor(0.4001, grad_fn=<NllLossBackward>)
# tensor(0.1157, grad_fn=<NllLossBackward>)
# tensor(0.3015, grad_fn=<NllLossBackward>)
# tensor(0.0269, grad_fn=<NllLossBackward>)
# tensor(0.1838, grad_fn=<NllLossBackward>)
# tensor(0.3395, grad_fn=<NllLossBackward>)
# tensor(0.1301, grad_fn=<NllLossBackward>)
# tensor(0.1124, grad_fn=<NllLossBackward>)
# tensor(0.2705, grad_fn=<NllLossBackward>)
# tensor(0.2328, grad_fn=<NllLossBackward>)
# tensor(0.0753, grad_fn=<NllLossBackward>)
# tensor(0.1228, grad_fn=<NllLossBackward>)
# tensor(0.2837, grad_fn=<NllLossBackward>)
# tensor(0.0999, grad_fn=<NllLossBackward>)
# tensor(0.3718, grad_fn=<NllLossBackward>)
# tensor(0.2217, grad_fn=<NllLossBackward>)
# tensor(0.3375, grad_fn=<NllLossBackward>)
# tensor(0.1403, grad_fn=<NllLossBackward>)
# tensor(0.1660, grad_fn=<NllLossBackward>)
# tensor(0.1026, grad_fn=<NllLossBackward>)
# tensor(0.3219, grad_fn=<NllLossBackward>)
# tensor(0.1800, grad_fn=<NllLossBackward>)
# tensor(0.1269, grad_fn=<NllLossBackward>)
# tensor(0.2162, grad_fn=<NllLossBackward>)
# tensor(0.2560, grad_fn=<NllLossBackward>)
# tensor(0.1823, grad_fn=<NllLossBackward>)
# tensor(0.0877, grad_fn=<NllLossBackward>)
# tensor(0.0822, grad_fn=<NllLossBackward>)
# tensor(0.1697, grad_fn=<NllLossBackward>)
# tensor(0.2624, grad_fn=<NllLossBackward>)
# tensor(0.6019, grad_fn=<NllLossBackward>)
# tensor(0.3344, grad_fn=<NllLossBackward>)
# tensor(0.2839, grad_fn=<NllLossBackward>)
# tensor(0.2668, grad_fn=<NllLossBackward>)
# tensor(0.1765, grad_fn=<NllLossBackward>)
# tensor(0.1520, grad_fn=<NllLossBackward>)
# tensor(0.3330, grad_fn=<NllLossBackward>)
# tensor(0.3082, grad_fn=<NllLossBackward>)
# tensor(0.2123, grad_fn=<NllLossBackward>)
# tensor(0.1781, grad_fn=<NllLossBackward>)
# tensor(0.1057, grad_fn=<NllLossBackward>)
# tensor(0.4067, grad_fn=<NllLossBackward>)
# tensor(0.2245, grad_fn=<NllLossBackward>)
# tensor(0.1441, grad_fn=<NllLossBackward>)
# tensor(0.3174, grad_fn=<NllLossBackward>)
# tensor(0.2114, grad_fn=<NllLossBackward>)
# tensor(0.5059, grad_fn=<NllLossBackward>)
# tensor(0.1156, grad_fn=<NllLossBackward>)
# tensor(0.1240, grad_fn=<NllLossBackward>)
# tensor(0.1205, grad_fn=<NllLossBackward>)
# tensor(0.0900, grad_fn=<NllLossBackward>)
# tensor(0.3412, grad_fn=<NllLossBackward>)
# tensor(0.0812, grad_fn=<NllLossBackward>)
# tensor(0.1889, grad_fn=<NllLossBackward>)
# tensor(0.3223, grad_fn=<NllLossBackward>)
# tensor(0.2190, grad_fn=<NllLossBackward>)
# tensor(0.0620, grad_fn=<NllLossBackward>)
# tensor(0.1218, grad_fn=<NllLossBackward>)
# tensor(0.3661, grad_fn=<NllLossBackward>)
# tensor(0.0798, grad_fn=<NllLossBackward>)
# tensor(0.0496, grad_fn=<NllLossBackward>)
# tensor(0.0384, grad_fn=<NllLossBackward>)
# tensor(0.1150, grad_fn=<NllLossBackward>)
# tensor(0.0712, grad_fn=<NllLossBackward>)
# tensor(0.1676, grad_fn=<NllLossBackward>)
# tensor(0.2662, grad_fn=<NllLossBackward>)
# tensor(0.2253, grad_fn=<NllLossBackward>)
# tensor(0.1233, grad_fn=<NllLossBackward>)
# tensor(0.0841, grad_fn=<NllLossBackward>)
# tensor(0.0545, grad_fn=<NllLossBackward>)
# tensor(0.2228, grad_fn=<NllLossBackward>)
# tensor(0.1829, grad_fn=<NllLossBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-9-fd630ed70915> in train(epoch, losst, acct, log_interval)
#       7
#       8     # Loop over each batch from the training set
# ----> 9     for batch_idx, (data, target) in enumerate(train_loader):
#      10         # Copy data to GPU if needed
#      11         data = data.to(device)
#
# ~/miniforge3/envs/LanguageProcessing100/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/miniforge3/envs/LanguageProcessing100/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# ~/miniforge3/envs/LanguageProcessing100/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/miniforge3/envs/LanguageProcessing100/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/miniforge3/envs/LanguageProcessing100/lib/python3.8/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#     125             tuple: (image, target) where target is index of the target class.
#     126         """
# --> 127         img, target = self.data[index], int(self.targets[index])
#     128
#     129         # doing this so that it is consistent with all other datasets
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), lossv)
plt.title('validation loss')

plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), accv)
plt.title('validation accuracy')
# Out:
# Text(0.5, 1.0, 'validation accuracy')

# %%
plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), losst)
plt.title('train loss')

plt.figure(figsize=(5,3))
plt.plot(np.arange(1,epochs+1), acct)
plt.title('train accuracy')
# Out:
# Text(0.5, 1.0, 'train accuracy')
